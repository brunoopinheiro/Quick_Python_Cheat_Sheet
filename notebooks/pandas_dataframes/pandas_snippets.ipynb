# %% [markdown]
# # Working with Pandas Library (Dataframes)

# %% [markdown]
# In this project, the `pandas` module is already installed. If you need, you can run:
# ```bash
# pip install pandas
# ```
# For more information, check the [Pandas advanced installation page](https://pandas.pydata.org/docs/getting_started/install.html#install-pypi).
#
# ---
#
# For the dataset manipulation, we will use the [Coffe Quality Data (CQI May-2023)](https://www.kaggle.com/datasets/fatihb/coffee-quality-data-cqi) from **Kaggle**.

# %% [markdown]
# ### 1. Creating a DataFrame
# To create a DataFrame with you own columns and data:

# %%
import pandas as pd

data = {
    'Element': ['Earth', 'Water', 'Fire', 'Air'],
    'Symbol': ['🜃', '🜄', '🜂', '🜁'],
}

df = pd.DataFrame(data)

(df)
# Out:
#   Element Symbol
# 0   Earth      🜃
# 1   Water      🜄
# 2    Fire      🜂
# 3     Air      🜁

# %% [markdown]
# ### 2. Reading Data from a CSV file
# To read data from a CSV file, transforming it into a DataFrame:

# %%
df = pd.read_csv('df_arabica_clean.csv')

# %% [markdown]
# ### 3. Inspecting the First Few Rows
# To get the first rows from the DataFrame:

# %%
(df.head()) # By default, it shows 5 rows
# Out:
#    Unnamed: 0  ID Country of Origin                 Farm Name  \
# 0           0   0          Colombia          Finca El Paraiso
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
# 3           3   3        Costa Rica                 La Cumbre
# 4           4   4          Colombia           Finca Santuario
#
#                                 Lot Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
# 3                               CQU2022017        La Montana Tarrazu MIll
# 4                               CQU2023002                Finca Santuario
#
#   ICO Number                   Company   Altitude                Region  ...  \
# 0        NaN      Coffee Quality Union  1700-1930        Piendamo,Cauca  ...
# 1        NaN  Taiwan Coffee Laboratory       1200                Chiayi  ...
# 2        NaN  Taiwan Coffee Laboratory       1300  Laos Borofen Plateau  ...
# 3        NaN      Coffee Quality Union       1900    Los Santos,Tarrazu  ...
# 4        NaN      Coffee Quality Union  1850-2100         Popayan,Cauca  ...
#
#   Total Cup Points  Moisture Percentage Category One Defects Quakers  \
# 0            89.33                 11.8                    0       0
# 1            87.58                 10.5                    0       0
# 2            87.42                 10.4                    0       0
# 3            87.17                 11.8                    0       0
# 4            87.08                 11.6                    0       2
#
#           Color Category Two Defects            Expiration  \
# 0         green                    3  September 21st, 2023
# 1    blue-green                    0   November 15th, 2023
# 2     yellowish                    2   November 15th, 2023
# 3         green                    0  September 21st, 2023
# 4  yellow-green                    2       March 5th, 2024
#
#                  Certification Body  \
# 0             Japan Coffee Exchange
# 1  Taiwan Coffee Laboratory 台灣咖啡研究室
# 2  Taiwan Coffee Laboratory 台灣咖啡研究室
# 3             Japan Coffee Exchange
# 4             Japan Coffee Exchange
#
#                                Certification Address  \
# 0  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
# 1  QAHWAH CO., LTD 4F, No. 225, Sec. 3, Beixin Rd...
# 2  QAHWAH CO., LTD 4F, No. 225, Sec. 3, Beixin Rd...
# 3  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
# 4  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
#
#                      Certification Contact
# 0  松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
# 1     Lin, Jen-An Neil 林仁安 - 886-289116612
# 2     Lin, Jen-An Neil 林仁安 - 886-289116612
# 3  松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
# 4  松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
#
# [5 rows x 41 columns]

# %%
(df.head(7)) # But you can show another amount
# Out:
#    Unnamed: 0  ID Country of Origin                        Farm Name  \
# 0           0   0          Colombia                 Finca El Paraiso
# 1           1   1            Taiwan         Royal Bean Geisha Estate
# 2           2   2              Laos               OKLAO coffee farms
# 3           3   3        Costa Rica                        La Cumbre
# 4           4   4          Colombia                  Finca Santuario
# 5           5   5         Guatemala                        La Colina
# 6           6   6            Taiwan  野牡丹咖啡莊園 Melastoma Coffee Estate
#
#                                 Lot Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
# 3                               CQU2022017        La Montana Tarrazu MIll
# 4                               CQU2023002                Finca Santuario
# 5  The 2022 Pacific Rim Coffee Summit,GT02                  Dinámica Café
# 6  The 2022 Pacific Rim Coffee Summit,T034                          野牡丹咖啡
#
#   ICO Number                   Company   Altitude                Region  ...  \
# 0        NaN      Coffee Quality Union  1700-1930        Piendamo,Cauca  ...
# 1        NaN  Taiwan Coffee Laboratory       1200                Chiayi  ...
# 2        NaN  Taiwan Coffee Laboratory       1300  Laos Borofen Plateau  ...
# 3        NaN      Coffee Quality Union       1900    Los Santos,Tarrazu  ...
# 4        NaN      Coffee Quality Union  1850-2100         Popayan,Cauca  ...
# 5        NaN  Taiwan Coffee Laboratory       1668         Chimaltenango  ...
# 6        NaN  Taiwan Coffee Laboratory       1250                Chiayi  ...
#
#   Total Cup Points  Moisture Percentage Category One Defects Quakers  \
# 0            89.33                 11.8                    0       0
# 1            87.58                 10.5                    0       0
# 2            87.42                 10.4                    0       0
# 3            87.17                 11.8                    0       0
# 4            87.08                 11.6                    0       2
# 5            87.00                 10.7                    0       0
# 6            86.92                  9.1                    0       0
#
#           Color Category Two Defects            Expiration  \
# 0         green                    3  September 21st, 2023
# 1    blue-green                    0   November 15th, 2023
# 2     yellowish                    2   November 15th, 2023
# 3         green                    0  September 21st, 2023
# 4  yellow-green                    2       March 5th, 2024
# 5         green                    2   November 15th, 2023
# 6         green                    0   November 15th, 2023
#
#                  Certification Body  \
# 0             Japan Coffee Exchange
# 1  Taiwan Coffee Laboratory 台灣咖啡研究室
# 2  Taiwan Coffee Laboratory 台灣咖啡研究室
# 3             Japan Coffee Exchange
# 4             Japan Coffee Exchange
# 5  Taiwan Coffee Laboratory 台灣咖啡研究室
# 6  Taiwan Coffee Laboratory 台灣咖啡研究室
#
#                                Certification Address  \
# 0  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
# 1  QAHWAH CO., LTD 4F, No. 225, Sec. 3, Beixin Rd...
# 2  QAHWAH CO., LTD 4F, No. 225, Sec. 3, Beixin Rd...
# 3  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
# 4  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
# 5  QAHWAH CO., LTD 4F, No. 225, Sec. 3, Beixin Rd...
# 6  QAHWAH CO., LTD 4F, No. 225, Sec. 3, Beixin Rd...
#
#                      Certification Contact
# 0  松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
# 1     Lin, Jen-An Neil 林仁安 - 886-289116612
# 2     Lin, Jen-An Neil 林仁安 - 886-289116612
# 3  松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
# 4  松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
# 5     Lin, Jen-An Neil 林仁安 - 886-289116612
# 6     Lin, Jen-An Neil 林仁安 - 886-289116612
#
# [7 rows x 41 columns]

# %% [markdown]
# ### 4. Selecting Columns
# To select specific columns from a dataframe:

# %%
# You can access all columns of the dataset
df_columns = df.columns
(df_columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'Country of Origin', 'Farm Name', 'Lot Number',
#        'Mill', 'ICO Number', 'Company', 'Altitude', 'Region', 'Producer',
#        'Number of Bags', 'Bag Weight', 'In-Country Partner', 'Harvest Year',
#        'Grading Date', 'Owner', 'Variety', 'Status', 'Processing Method',
#        'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance',
#        'Uniformity', 'Clean Cup', 'Sweetness', 'Overall', 'Defects',
#        'Total Cup Points', 'Moisture Percentage', 'Category One Defects',
#        'Quakers', 'Color', 'Category Two Defects', 'Expiration',
#        'Certification Body', 'Certification Address', 'Certification Contact'],
#       dtype='object')

# %%
# Select a single column
farm_names = df['Farm Name']

(farm_names)
# Out:
# 0                          Finca El Paraiso
# 1                  Royal Bean Geisha Estate
# 2                        OKLAO coffee farms
# 3                                 La Cumbre
# 4                           Finca Santuario
#                        ...
# 202                       Fazenda Conquista
# 203                        Finca San Felipe
# 204                                       -
# 205    Rosario de Maria II, Area de La Pila
# 206                           Walter Matter
# Name: Farm Name, Length: 207, dtype: object

# %%
# Or get multiple columns

sub_df = df[['Farm Name', 'Lot Number', 'Mill', 'Variety', 'Acidity']]

(sub_df)
# Out:
#                                 Farm Name  \
# 0                        Finca El Paraiso
# 1                Royal Bean Geisha Estate
# 2                      OKLAO coffee farms
# 3                               La Cumbre
# 4                         Finca Santuario
# ..                                    ...
# 202                     Fazenda Conquista
# 203                      Finca San Felipe
# 204                                     -
# 205  Rosario de Maria II, Area de La Pila
# 206                         Walter Matter
#
#                                   Lot Number  \
# 0                                 CQU2022015
# 1    The 2022 Pacific Rim Coffee Summit,T037
# 2    The 2022 Pacific Rim Coffee Summit,LA01
# 3                                 CQU2022017
# 4                                 CQU2023002
# ..                                       ...
# 202                                   019/22
# 203                             017-053-0155
# 204                         105/3/VL7285-005
# 205                                  0423A01
# 206                              1058 y 1059
#
#                                           Mill      Variety  Acidity
# 0                             Finca El Paraiso     Castillo     8.58
# 1                     Royal Bean Geisha Estate        Gesha     8.00
# 2                oklao coffee processing plant         Java     8.17
# 3                      La Montana Tarrazu MIll        Gesha     8.25
# 4                              Finca Santuario  Red Bourbon     8.25
# ..                                         ...          ...      ...
# 202                                   Dry Mill   Mundo Novo     7.17
# 203                  Beneficio Atlantic Sébaco          SHG     7.17
# 204                                   DRY MILL      Catimor     7.00
# 205  Optimum Coffee, San Salvador, El Salvador   Maragogype     7.17
# 206                      Beneficio humedo/seco   Mundo Novo     6.83
#
# [207 rows x 5 columns]

# %% [markdown]
# ### 5. Filtering Rows
# You can select rows based on a criteria:

# %%
low_accidity = df[df['Acidity'] <= 7]

(low_accidity)
# Out:
#      Unnamed: 0   ID Country of Origin      Farm Name        Lot Number  \
# 204         204  204              Laos              -  105/3/VL7285-005
# 206         206  206            Brazil  Walter Matter       1058 y 1059
#
#                       Mill        ICO Number  \
# 204               DRY MILL  105/3/VL7285-005
# 206  Beneficio humedo/seco     002/1208/1016
#
#                                 Company  Altitude           Region  ...  \
# 204                Marubeni Corporation      1300  Bolaven Plateau  ...
# 206  Descafeinadores Mexicano SA. de CV  850-1100     Minas Gerais  ...
#
#     Total Cup Points  Moisture Percentage Category One Defects Quakers  Color  \
# 204            79.67                 11.6                    0       9  green
# 206            78.00                 11.3                    0       0  green
#
#     Category Two Defects           Expiration  \
# 204                   11  November 11th, 2023
# 206                    1  November 18th, 2023
#
#                      Certification Body  \
# 204               Japan Coffee Exchange
# 206  Centro Agroecológico del Café A.C.
#
#                                  Certification Address  \
# 204  〒413-0002 静岡県熱海市伊豆山１１７３−５８ 1173-58 Izusan, Ata...
# 206  Instituto de Ecología A. C., Campus III Edific...
#
#                                  Certification Contact
# 204            松澤　宏樹　Koju Matsuzawa - +81(0)9085642901
# 206  Stephany Escamilla Femat - Tel. +52 228 842180...
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 6. Creating New Columns
# You can create new columns in the DataFrame, derived from the data within:

# %%
# We have some scores from different aspects of each coffe

eval_df = df[['ID', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity',
            'Body', 'Balance', 'Uniformity', 'Clean Cup',
            'Sweetness', 'Overall', 'Total Cup Points']]

(eval_df)
# Out:
#       ID  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  \
# 0      0   8.58    8.50        8.42     8.58  8.25     8.42        10.0
# 1      1   8.50    8.50        7.92     8.00  7.92     8.25        10.0
# 2      2   8.33    8.42        8.08     8.17  7.92     8.17        10.0
# 3      3   8.08    8.17        8.17     8.25  8.17     8.08        10.0
# 4      4   8.33    8.33        8.08     8.25  7.92     7.92        10.0
# ..   ...    ...     ...         ...      ...   ...      ...         ...
# 202  202   7.17    7.17        6.92     7.17  7.42     7.17        10.0
# 203  203   7.33    7.08        6.75     7.17  7.42     7.17        10.0
# 204  204   7.25    7.17        7.08     7.00  7.08     7.08        10.0
# 205  205   6.50    6.75        6.75     7.17  7.08     7.00        10.0
# 206  206   7.25    7.08        6.67     6.83  6.83     6.67        10.0
#
#      Clean Cup  Sweetness  Overall  Total Cup Points
# 0         10.0       10.0     8.58             89.33
# 1         10.0       10.0     8.50             87.58
# 2         10.0       10.0     8.33             87.42
# 3         10.0       10.0     8.25             87.17
# 4         10.0       10.0     8.25             87.08
# ..         ...        ...      ...               ...
# 202       10.0       10.0     7.08             80.08
# 203       10.0       10.0     7.08             80.00
# 204       10.0       10.0     7.00             79.67
# 205       10.0       10.0     6.83             78.08
# 206       10.0       10.0     6.67             78.00
#
# [207 rows x 12 columns]

# %%
# Lets get the average pontuation for each coffe in a new column
eval_df['Avg. Points'] = eval_df[['Aroma', 'Flavor', 'Aftertaste', 'Acidity',
            'Body', 'Balance', 'Uniformity', 'Clean Cup',
            'Sweetness', 'Overall']].mean(axis=1)

(eval_df)
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_10996\1535358830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df['Avg. Points'] = eval_df[['Aroma', 'Flavor', 'Aftertaste', 'Acidity',
#       ID  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  \
# 0      0   8.58    8.50        8.42     8.58  8.25     8.42        10.0
# 1      1   8.50    8.50        7.92     8.00  7.92     8.25        10.0
# 2      2   8.33    8.42        8.08     8.17  7.92     8.17        10.0
# 3      3   8.08    8.17        8.17     8.25  8.17     8.08        10.0
# 4      4   8.33    8.33        8.08     8.25  7.92     7.92        10.0
# ..   ...    ...     ...         ...      ...   ...      ...         ...
# 202  202   7.17    7.17        6.92     7.17  7.42     7.17        10.0
# 203  203   7.33    7.08        6.75     7.17  7.42     7.17        10.0
# 204  204   7.25    7.17        7.08     7.00  7.08     7.08        10.0
# 205  205   6.50    6.75        6.75     7.17  7.08     7.00        10.0
# 206  206   7.25    7.08        6.67     6.83  6.83     6.67        10.0
#
#      Clean Cup  Sweetness  Overall  Total Cup Points  Avg. Points
# 0         10.0       10.0     8.58             89.33        8.933
# 1         10.0       10.0     8.50             87.58        8.759
# 2         10.0       10.0     8.33             87.42        8.742
# 3         10.0       10.0     8.25             87.17        8.717
# 4         10.0       10.0     8.25             87.08        8.708
# ..         ...        ...      ...               ...          ...
# 202       10.0       10.0     7.08             80.08        8.010
# 203       10.0       10.0     7.08             80.00        8.000
# 204       10.0       10.0     7.00             79.67        7.966
# 205       10.0       10.0     6.83             78.08        7.808
# 206       10.0       10.0     6.67             78.00        7.800
#
# [207 rows x 13 columns]

# %% [markdown]
# ### 7. Grouping and Aggregating Data
# To gather your data into groups and extract new data through aggregation:

# %%
country_groups = df.groupby('Country of Origin').aggregate('size')

(country_groups)
# Out:
# Country of Origin
# Brazil                          10
# Colombia                        19
# Costa Rica                       8
# El Salvador                      7
# Ethiopia                        11
# Guatemala                       21
# Honduras                        13
# Indonesia                        3
# Kenya                            2
# Laos                             3
# Madagascar                       1
# Mexico                           4
# Myanmar                          1
# Nicaragua                        7
# Panama                           2
# Peru                             4
# Taiwan                          61
# Tanzania, United Republic Of     6
# Thailand                        12
# Uganda                           3
# United States (Hawaii)           5
# Vietnam                          4
# dtype: int64

# %% [markdown]
# ### 8. Merging DataFrames
# To merge two DataFrames, joining them by a shared key:

# %%
df1 = pd.DataFrame({
    'Element': ['Earth', 'Water', 'Fire', 'Air', 'Aether'],
    'Symbol': ['🜃', '🜄', '🜂', '🜁', None],
})

df2 = pd.DataFrame({'Element': ['Earth', 'Fire'], 'Quality': ['Solid', 'Plasma']})
merged_df = pd.merge(df1, df2, on='Element')

(merged_df)
# Out:
#   Element Symbol Quality
# 0   Earth      🜃   Solid
# 1    Fire      🜂  Plasma

# %% [markdown]
# ### 9. Handling Missing Data
# To clean your DataFrame, filling the voids where data is absent:

# %%
(df1)
# Out:
#   Element Symbol
# 0   Earth      🜃
# 1   Water      🜄
# 2    Fire      🜂
# 3     Air      🜁
# 4  Aether   None

# %%
df1.fillna(value='Unknown', inplace=True)

(df1)
# Out:
#   Element   Symbol
# 0   Earth        🜃
# 1   Water        🜄
# 2    Fire        🜂
# 3     Air        🜁
# 4  Aether  Unknown

# %% [markdown]
# ### 10. Pivoting and Reshaping Data
# To transmute and shape your DataFrame, revealing hidden patterns and structures with a pivot operation:

# %%
df1['Length'] = df1['Element'].apply(len)

pivoted_df = df1.pivot(index='Element', columns='Symbol', values='Length')

(pivoted_df)
# Out:
# Symbol   Unknown    🜁    🜂    🜃    🜄
# Element
# Aether       6.0  NaN  NaN  NaN  NaN
# Air          NaN  3.0  NaN  NaN  NaN
# Earth        NaN  NaN  NaN  5.0  NaN
# Fire         NaN  NaN  4.0  NaN  NaN
# Water        NaN  NaN  NaN  NaN  5.0
