# %% [markdown]
# # Working with Matplotlib Library (Data Visualization)

# %% [markdown]
# In this project, the `matplotlib` module is already installed. If you need, you can run:
# ```bash
# pip install matplotlib
# ```
# For more information, check the [Matplotlib installation page](https://matplotlib.org/stable/).
#
# ---

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Creating a Basic Plot
# To create a plot visualization:

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 2. Adding Titles and Labels
# To create names for axes and title your plot to give better context:

# %%
plt.plot(x, y)
plt.title('Growth Over Time')
plt.xlabel('Time')
plt.ylabel('Growth')
plt.show()

# %% [markdown]
# ### 3. Creating a Scatter Plot
# To create a scatter plot:

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 4. Customizing Line Styles and Markers
# To add symbols into your plot, enriching its usefulness:

# %%
plt.plot(x, y, linestyle='--', marker='o', color='b')
plt.show()

# %% [markdown]
# ### 5. Creating Multiple Plots on the Same Axes
# Creating multiple plots:

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [2, 3, 4, 5, 6]

plt.plot(x, y)
plt.plot(x, z)
plt.show()

# %% [markdown]
# ### 6. Creating Subplots
# You can create subplots in your plot:

# %%
fig, ax = plt.subplots(2, 1) # 2 rows, 1 column
ax[0].plot(x, y)
ax[1].plot(x, z)

plt.show()

# %% [markdown]
# ### 7. Creating a Histogram
# To create a histogram:

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
plt.hist(data, bins=4)
plt.show()

# %% [markdown]
# ### 8. Adding a Legend
# To create a legend to your plot:

# %%
plt.plot(x, y, label='Growth')
plt.plot(x, z, label='Decay')
plt.legend()
plt.show()

# %% [markdown]
# ### 9. Customizing Ticks
# To create your own marks upon the axes, defining the scale of your values:

# %%
plt.plot(x, y)
plt.xticks([1, 2, 3, 4, 5], ['One', 'Two', 'Three', 'Four', 'Five'])
plt.yticks([0, 5, 10, 15, 20, 25], ['0', '5', '10', '15', '20', '25+'])
plt.show()

# %% [markdown]
# ### 10. Saving Figures
# To save the plot as a `.png`:

# %%
plt.plot(x, y)
plt.savefig('growth_over_time.png')

# %% [markdown]
# Here is our [file](growth_over_time.png):
#
# <img src='growth_over_time.png' width=800px />
